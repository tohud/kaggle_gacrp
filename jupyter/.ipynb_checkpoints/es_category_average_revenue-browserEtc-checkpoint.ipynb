# %%
from matplotlib import pyplot
import numpy as np
import os

import elasticsearch as es
ES_HOST = "localhost"
escon = es.Elasticsearch(ES_HOST, port=9200)
GACRP_HOME=os.environ['GACRP_HOME']

# %%
# elasticsearch 接続確認
body = {
            "size":10,
            "query":{
                "match_all":{}
            }
        }
res=escon.search(index='gacrp_index',body=body)
print(res['hits']['total'])
print(res['hits']['hits'][0]['_source']['channelGrouping'])
# Out:
# 903653
# Organic Search

# %%
# esからデータ取得
body = {
    "size":0,
    "aggs":{
        "aggs_browser":{
            "terms":{
                "field":"browser.keyword"
            },
            "aggs":{
                "aggs_operatingSystem":{
                    "terms":{"field":"operatingSystem.keyword"},
                    "aggs":{
                        "aggs_isMobile":{
                            "terms":{"field":"isMobile.keyword"},
                            "aggs":{
                                "aggs_deviceCategory":{
                                    "terms":{"field":"deviceCategory.keyword"},
                                    "aggs":{
                                        "aggs_transactionRevenue":{
                                            "avg":{"field":"transactionRevenue"}
                                        }
                                    }
                                }
                            }
                        }
                    }   
                }
            }
        }
    }
}

res=escon.search(index='gacrp_index',body=body)
#restmp=res['aggregations']['aggs_browser']['buckets']
#print("transactionRevenue:",res['aggregations']['aggs_browser']['buckets'][0]['aggs_operatingSystem']['buckets'][0]['aggs_isMobile']['buckets'][0]['aggs_deviceCategory']['buckets'][0]['aggs_transactionRevenue']['value'])
#print("count:",res['aggregations']['aggs_browser']['buckets'][0]['aggs_operatingSystem']['buckets'][0]['aggs_isMobile']['buckets'][0]['aggs_deviceCategory']['buckets'][0]['doc_count'])

i_browser=len(res['aggregations']['aggs_browser']['buckets'])

data=[]
for i in range(len(res)):
    resSub_browser = res['aggregations']['aggs_browser']['buckets']
    for i_browser in range(len(resSub_browser)):
        resSub_operatingSystem = resSub_browser[i_browser]['aggs_operatingSystem']['buckets']
        for i_operatingSystem in range(len(resSub_operatingSystem)):
            resSub_isMobile = resSub_operatingSystem[i_operatingSystem]['aggs_isMobile']['buckets']
            for i_isMobile in range(len(resSub_isMobile)):
                resSub_deviceCategory = resSub_isMobile[i_isMobile]['aggs_deviceCategory']['buckets']
                for i_deviceCategory in range(len(resSub_deviceCategory)):
                    res_tr=resSub_deviceCategory[i_deviceCategory]['aggs_transactionRevenue']['value']
                    res_cnt=resSub_deviceCategory[i_deviceCategory]['doc_count']
                    if res_cnt == 0:
                        continue
                        
                    res_brw=resSub_browser[i_browser]['key']
                    res_os =resSub_operatingSystem[i_operatingSystem]['key']
                    res_isM=resSub_isMobile[i_isMobile]['key']
                    res_dv =resSub_deviceCategory[i_deviceCategory]['key']
                    print(res_brw+'-'+res_os+'-'+res_isM+'-'+res_dv,res_cnt,res_tr)
                    data.append([res_brw+'-'+res_os+'-'+res_isM+'-'+res_dv,res_cnt,res_tr])

#print(data.sort(key=lambda x:x[1]))

exit()
# Out:
# (u'Chrome-Windows-FALSE-desktop', 284522, 1041826.2208194797)
# (u'Chrome-Windows-FALSE-mobile', 7, 0.0)
# (u'Chrome-Windows-TRUE-mobile', 3, 0.0)
# (u'Chrome-Windows-TRUE-desktop', 1, 0.0)
# (u'Chrome-Macintosh-FALSE-desktop', 156187, 5242908.820836562)
# (u'Chrome-Macintosh-FALSE-mobile', 7, 0.0)
# (u'Chrome-Macintosh-TRUE-mobile', 7, 0.0)
# (u'Chrome-Android-TRUE-mobile', 101953, 322134.512961855)
# (u'Chrome-Android-TRUE-tablet', 7810, 419001.2804097311)
# (u'Chrome-Android-TRUE-desktop', 76, 460394.7368421053)
# (u'Chrome-Android-FALSE-desktop', 4, 0.0)
# (u'Chrome-Linux-FALSE-desktop', 30966, 1415475.3600723373)
# (u'Chrome-Linux-FALSE-mobile', 91, 27802.197802197803)
# (u'Chrome-Linux-FALSE-tablet', 10, 0.0)
# (u'Chrome-Linux-TRUE-mobile', 10, 0.0)
# (u'Chrome-Linux-TRUE-desktop', 1, 0.0)
# (u'Chrome-Linux-TRUE-tablet', 1, 0.0)
# (u'Chrome-Chrome OS-FALSE-desktop', 26337, 6984005.391654327)
# (u'Chrome-iOS-TRUE-mobile', 9680, 328922.52066115703)
# (u'Chrome-iOS-TRUE-tablet', 2533, 277319.3841294907)
# (u'Chrome-iOS-TRUE-desktop', 6, 0.0)
# (u'Chrome-iOS-FALSE-desktop', 1, 0.0)
# (u'Chrome-(not set)-FALSE-desktop', 145, 0.0)
# (u'Chrome-FreeBSD-FALSE-desktop', 3, 0.0)
# (u'Chrome-BlackBerry-TRUE-mobile', 2, 0.0)
# (u'Chrome-Windows Phone-TRUE-mobile', 1, 0.0)
# (u'Safari-Macintosh-FALSE-desktop', 92137, 371667.9509860317)
# (u'Safari-Macintosh-FALSE-mobile', 25, 0.0)
# (u'Safari-Macintosh-FALSE-tablet', 4, 0.0)
# (u'Safari-iOS-TRUE-mobile', 71029, 180270.45291359868)
# (u'Safari-iOS-TRUE-tablet', 17446, 305071.6496618136)
# (u'Safari-iOS-TRUE-desktop', 15, 0.0)
# (u'Safari-iOS-FALSE-desktop', 2, 0.0)
# (u'Safari-Windows Phone-TRUE-mobile', 911, 28979.14379802415)
# (u'Safari-Linux-FALSE-desktop', 650, 0.0)
# (u'Safari-Windows-FALSE-desktop', 25, 0.0)
# (u'Safari-(not set)-FALSE-desktop', 1, 0.0)
# (u'Firefox-Windows-FALSE-desktop', 28346, 3033277.0055739786)
# (u'Firefox-Macintosh-FALSE-desktop', 5256, 611171.9939117199)
# (u'Firefox-Linux-FALSE-desktop', 2227, 34243.37674000898)
# (u'Firefox-Android-TRUE-mobile', 1136, 40906.69014084507)
# (u'Firefox-Android-TRUE-tablet', 6, 0.0)
# (u'Firefox-Firefox OS-TRUE-mobile', 87, 0.0)
# (u'Firefox-Firefox OS-TRUE-tablet', 2, 0.0)
# (u'Firefox-FreeBSD-FALSE-desktop', 6, 0.0)
# (u'Firefox-OpenBSD-FALSE-desktop', 2, 0.0)
# (u'Firefox-SunOS-FALSE-desktop', 1, 0.0)
# (u'Internet Explorer-Windows-FALSE-desktop', 17798, 424234.18361613667)
# (u'Internet Explorer-Windows-FALSE-mobile', 4, 0.0)
# (u'Internet Explorer-Windows-TRUE-mobile', 895, 736055.8659217877)
# (u'Internet Explorer-Windows-TRUE-tablet', 394, 117411.16751269036)
# (u'Internet Explorer-Windows-TRUE-desktop', 4, 0.0)
# (u'Internet Explorer-Windows Phone-TRUE-mobile', 269, 0.0)
# (u'Internet Explorer-Windows Phone-TRUE-tablet', 1, 0.0)
# (u'Internet Explorer-Xbox-FALSE-desktop', 7, 0.0)
# (u'Internet Explorer-Macintosh-FALSE-desktop', 2, 0.0)
# (u'Internet Explorer-(not set)-FALSE-desktop', 1, 0.0)
# (u'Edge-Windows-FALSE-desktop', 9832, 659374.4914564687)
# (u'Edge-Windows-FALSE-mobile', 1, 0.0)
# (u'Edge-Windows-TRUE-mobile', 305, 0.0)
# (u'Edge-Windows-TRUE-tablet', 5, 0.0)
# (u'Edge-Windows-TRUE-desktop', 1, 0.0)
# (u'Edge-Xbox-FALSE-desktop', 59, 0.0)
# (u'Edge-(not set)-FALSE-desktop', 2, 0.0)
# (u'Android Webview-Android-TRUE-mobile', 7286, 12610.485863299478)
# (u'Android Webview-Android-TRUE-tablet', 575, 39947.82608695652)
# (u'Android Webview-Android-FALSE-desktop', 4, 0.0)
# (u'Safari (in-app)-iOS-TRUE-mobile', 5905, 21808.636748518205)
# (u'Safari (in-app)-iOS-TRUE-tablet', 939, 26613.41853035144)
# (u'Safari (in-app)-iOS-FALSE-desktop', 5, 0.0)
# (u'Safari (in-app)-iOS-FALSE-mobile', 1, 0.0)
# (u'Opera Mini-(not set)-TRUE-mobile', 4077, 0.0)
# (u'Opera Mini-(not set)-TRUE-tablet', 34, 0.0)
# (u'Opera Mini-Android-TRUE-mobile', 1687, 0.0)
# (u'Opera Mini-Samsung-TRUE-mobile', 280, 0.0)
# (u'Opera Mini-BlackBerry-TRUE-mobile', 31, 0.0)
# (u'Opera Mini-Windows Phone-TRUE-mobile', 27, 0.0)
# (u'Opera Mini-iOS-TRUE-mobile', 2, 0.0)
# (u'Opera Mini-iOS-TRUE-tablet', 1, 0.0)
# (u'Opera-Windows-FALSE-desktop', 4706, 36219.71950701233)
# (u'Opera-Android-TRUE-mobile', 549, 0.0)
# (u'Opera-Android-TRUE-tablet', 39, 0.0)
# (u'Opera-Android-TRUE-desktop', 2, 0.0)
# (u'Opera-Macintosh-FALSE-desktop', 210, 213809.52380952382)
# (u'Opera-Linux-FALSE-desktop', 127, 0.0)
# (u'Opera-Linux-FALSE-mobile', 10, 0.0)
# (u'UC Browser-Android-TRUE-mobile', 1469, 0.0)
# (u'UC Browser-Android-TRUE-tablet', 25, 0.0)
# (u'UC Browser-Android-TRUE-desktop', 1, 0.0)
# (u'UC Browser-Linux-FALSE-desktop', 846, 0.0)
# (u'UC Browser-Linux-FALSE-mobile', 1, 0.0)
# (u'UC Browser-iOS-TRUE-mobile', 56, 0.0)
# (u'UC Browser-iOS-TRUE-tablet', 10, 0.0)
# (u'UC Browser-Windows-FALSE-desktop', 8, 0.0)
# (u'UC Browser-Windows-TRUE-tablet', 3, 0.0)
# (u'UC Browser-Windows Phone-TRUE-mobile', 7, 0.0)
# (u'UC Browser-(not set)-FALSE-desktop', 1, 0.0)
# (u'Chrome-Windows-FALSE-desktop', 284522, 1041826.2208194797)
# (u'Chrome-Windows-FALSE-mobile', 7, 0.0)
# (u'Chrome-Windows-TRUE-mobile', 3, 0.0)
# (u'Chrome-Windows-TRUE-desktop', 1, 0.0)
# (u'Chrome-Macintosh-FALSE-desktop', 156187, 5242908.820836562)
# (u'Chrome-Macintosh-FALSE-mobile', 7, 0.0)
# (u'Chrome-Macintosh-TRUE-mobile', 7, 0.0)
# (u'Chrome-Android-TRUE-mobile', 101953, 322134.512961855)
# (u'Chrome-Android-TRUE-tablet', 7810, 419001.2804097311)
# (u'Chrome-Android-TRUE-desktop', 76, 460394.7368421053)
# (u'Chrome-Android-FALSE-desktop', 4, 0.0)
# (u'Chrome-Linux-FALSE-desktop', 30966, 1415475.3600723373)
# (u'Chrome-Linux-FALSE-mobile', 91, 27802.197802197803)
# (u'Chrome-Linux-FALSE-tablet', 10, 0.0)
# (u'Chrome-Linux-TRUE-mobile', 10, 0.0)
# (u'Chrome-Linux-TRUE-desktop', 1, 0.0)
# (u'Chrome-Linux-TRUE-tablet', 1, 0.0)
# (u'Chrome-Chrome OS-FALSE-desktop', 26337, 6984005.391654327)
# (u'Chrome-iOS-TRUE-mobile', 9680, 328922.52066115703)
# (u'Chrome-iOS-TRUE-tablet', 2533, 277319.3841294907)
# (u'Chrome-iOS-TRUE-desktop', 6, 0.0)
# (u'Chrome-iOS-FALSE-desktop', 1, 0.0)
# (u'Chrome-(not set)-FALSE-desktop', 145, 0.0)
# (u'Chrome-FreeBSD-FALSE-desktop', 3, 0.0)
# (u'Chrome-BlackBerry-TRUE-mobile', 2, 0.0)
# (u'Chrome-Windows Phone-TRUE-mobile', 1, 0.0)
# (u'Safari-Macintosh-FALSE-desktop', 92137, 371667.9509860317)
# (u'Safari-Macintosh-FALSE-mobile', 25, 0.0)
# (u'Safari-Macintosh-FALSE-tablet', 4, 0.0)
# (u'Safari-iOS-TRUE-mobile', 71029, 180270.45291359868)
# (u'Safari-iOS-TRUE-tablet', 17446, 305071.6496618136)
# (u'Safari-iOS-TRUE-desktop', 15, 0.0)
# (u'Safari-iOS-FALSE-desktop', 2, 0.0)
# (u'Safari-Windows Phone-TRUE-mobile', 911, 28979.14379802415)
# (u'Safari-Linux-FALSE-desktop', 650, 0.0)
# (u'Safari-Windows-FALSE-desktop', 25, 0.0)
# (u'Safari-(not set)-FALSE-desktop', 1, 0.0)
# (u'Firefox-Windows-FALSE-desktop', 28346, 3033277.0055739786)
# (u'Firefox-Macintosh-FALSE-desktop', 5256, 611171.9939117199)
# (u'Firefox-Linux-FALSE-desktop', 2227, 34243.37674000898)
# (u'Firefox-Android-TRUE-mobile', 1136, 40906.69014084507)
# (u'Firefox-Android-TRUE-tablet', 6, 0.0)
# (u'Firefox-Firefox OS-TRUE-mobile', 87, 0.0)
# (u'Firefox-Firefox OS-TRUE-tablet', 2, 0.0)
# (u'Firefox-FreeBSD-FALSE-desktop', 6, 0.0)
# (u'Firefox-OpenBSD-FALSE-desktop', 2, 0.0)
# (u'Firefox-SunOS-FALSE-desktop', 1, 0.0)
# (u'Internet Explorer-Windows-FALSE-desktop', 17798, 424234.18361613667)
# (u'Internet Explorer-Windows-FALSE-mobile', 4, 0.0)
# (u'Internet Explorer-Windows-TRUE-mobile', 895, 736055.8659217877)
# (u'Internet Explorer-Windows-TRUE-tablet', 394, 117411.16751269036)
# (u'Internet Explorer-Windows-TRUE-desktop', 4, 0.0)
# (u'Internet Explorer-Windows Phone-TRUE-mobile', 269, 0.0)
# (u'Internet Explorer-Windows Phone-TRUE-tablet', 1, 0.0)
# (u'Internet Explorer-Xbox-FALSE-desktop', 7, 0.0)
# (u'Internet Explorer-Macintosh-FALSE-desktop', 2, 0.0)
# (u'Internet Explorer-(not set)-FALSE-desktop', 1, 0.0)
# (u'Edge-Windows-FALSE-desktop', 9832, 659374.4914564687)
# (u'Edge-Windows-FALSE-mobile', 1, 0.0)
# (u'Edge-Windows-TRUE-mobile', 305, 0.0)
# (u'Edge-Windows-TRUE-tablet', 5, 0.0)
# (u'Edge-Windows-TRUE-desktop', 1, 0.0)
# (u'Edge-Xbox-FALSE-desktop', 59, 0.0)
# (u'Edge-(not set)-FALSE-desktop', 2, 0.0)
# (u'Android Webview-Android-TRUE-mobile', 7286, 12610.485863299478)
# (u'Android Webview-Android-TRUE-tablet', 575, 39947.82608695652)
# (u'Android Webview-Android-FALSE-desktop', 4, 0.0)
# (u'Safari (in-app)-iOS-TRUE-mobile', 5905, 21808.636748518205)
# (u'Safari (in-app)-iOS-TRUE-tablet', 939, 26613.41853035144)
# (u'Safari (in-app)-iOS-FALSE-desktop', 5, 0.0)
# (u'Safari (in-app)-iOS-FALSE-mobile', 1, 0.0)
# (u'Opera Mini-(not set)-TRUE-mobile', 4077, 0.0)
# (u'Opera Mini-(not set)-TRUE-tablet', 34, 0.0)
# (u'Opera Mini-Android-TRUE-mobile', 1687, 0.0)
# (u'Opera Mini-Samsung-TRUE-mobile', 280, 0.0)
# (u'Opera Mini-BlackBerry-TRUE-mobile', 31, 0.0)
# (u'Opera Mini-Windows Phone-TRUE-mobile', 27, 0.0)
# (u'Opera Mini-iOS-TRUE-mobile', 2, 0.0)
# (u'Opera Mini-iOS-TRUE-tablet', 1, 0.0)
# (u'Opera-Windows-FALSE-desktop', 4706, 36219.71950701233)
# (u'Opera-Android-TRUE-mobile', 549, 0.0)
# (u'Opera-Android-TRUE-tablet', 39, 0.0)
# (u'Opera-Android-TRUE-desktop', 2, 0.0)
# (u'Opera-Macintosh-FALSE-desktop', 210, 213809.52380952382)
# (u'Opera-Linux-FALSE-desktop', 127, 0.0)
# (u'Opera-Linux-FALSE-mobile', 10, 0.0)
# (u'UC Browser-Android-TRUE-mobile', 1469, 0.0)
# (u'UC Browser-Android-TRUE-tablet', 25, 0.0)
# (u'UC Browser-Android-TRUE-desktop', 1, 0.0)
# (u'UC Browser-Linux-FALSE-desktop', 846, 0.0)
# (u'UC Browser-Linux-FALSE-mobile', 1, 0.0)
# (u'UC Browser-iOS-TRUE-mobile', 56, 0.0)
# (u'UC Browser-iOS-TRUE-tablet', 10, 0.0)
# (u'UC Browser-Windows-FALSE-desktop', 8, 0.0)
# (u'UC Browser-Windows-TRUE-tablet', 3, 0.0)
# (u'UC Browser-Windows Phone-TRUE-mobile', 7, 0.0)
# (u'UC Browser-(not set)-FALSE-desktop', 1, 0.0)
# (u'Chrome-Windows-FALSE-desktop', 284522, 1041826.2208194797)
# (u'Chrome-Windows-FALSE-mobile', 7, 0.0)
# (u'Chrome-Windows-TRUE-mobile', 3, 0.0)
# (u'Chrome-Windows-TRUE-desktop', 1, 0.0)
# (u'Chrome-Macintosh-FALSE-desktop', 156187, 5242908.820836562)
# (u'Chrome-Macintosh-FALSE-mobile', 7, 0.0)
# (u'Chrome-Macintosh-TRUE-mobile', 7, 0.0)
# (u'Chrome-Android-TRUE-mobile', 101953, 322134.512961855)
# (u'Chrome-Android-TRUE-tablet', 7810, 419001.2804097311)
# (u'Chrome-Android-TRUE-desktop', 76, 460394.7368421053)
# (u'Chrome-Android-FALSE-desktop', 4, 0.0)
# (u'Chrome-Linux-FALSE-desktop', 30966, 1415475.3600723373)
# (u'Chrome-Linux-FALSE-mobile', 91, 27802.197802197803)
# (u'Chrome-Linux-FALSE-tablet', 10, 0.0)
# (u'Chrome-Linux-TRUE-mobile', 10, 0.0)
# (u'Chrome-Linux-TRUE-desktop', 1, 0.0)
# (u'Chrome-Linux-TRUE-tablet', 1, 0.0)
# (u'Chrome-Chrome OS-FALSE-desktop', 26337, 6984005.391654327)
# (u'Chrome-iOS-TRUE-mobile', 9680, 328922.52066115703)
# (u'Chrome-iOS-TRUE-tablet', 2533, 277319.3841294907)
# (u'Chrome-iOS-TRUE-desktop', 6, 0.0)
# (u'Chrome-iOS-FALSE-desktop', 1, 0.0)
# (u'Chrome-(not set)-FALSE-desktop', 145, 0.0)
# (u'Chrome-FreeBSD-FALSE-desktop', 3, 0.0)
# (u'Chrome-BlackBerry-TRUE-mobile', 2, 0.0)
# (u'Chrome-Windows Phone-TRUE-mobile', 1, 0.0)
# (u'Safari-Macintosh-FALSE-desktop', 92137, 371667.9509860317)
# (u'Safari-Macintosh-FALSE-mobile', 25, 0.0)
# (u'Safari-Macintosh-FALSE-tablet', 4, 0.0)
# (u'Safari-iOS-TRUE-mobile', 71029, 180270.45291359868)
# (u'Safari-iOS-TRUE-tablet', 17446, 305071.6496618136)
# (u'Safari-iOS-TRUE-desktop', 15, 0.0)
# (u'Safari-iOS-FALSE-desktop', 2, 0.0)
# (u'Safari-Windows Phone-TRUE-mobile', 911, 28979.14379802415)
# (u'Safari-Linux-FALSE-desktop', 650, 0.0)
# (u'Safari-Windows-FALSE-desktop', 25, 0.0)
# (u'Safari-(not set)-FALSE-desktop', 1, 0.0)
# (u'Firefox-Windows-FALSE-desktop', 28346, 3033277.0055739786)
# (u'Firefox-Macintosh-FALSE-desktop', 5256, 611171.9939117199)
# (u'Firefox-Linux-FALSE-desktop', 2227, 34243.37674000898)
# (u'Firefox-Android-TRUE-mobile', 1136, 40906.69014084507)
# (u'Firefox-Android-TRUE-tablet', 6, 0.0)
# (u'Firefox-Firefox OS-TRUE-mobile', 87, 0.0)
# (u'Firefox-Firefox OS-TRUE-tablet', 2, 0.0)
# (u'Firefox-FreeBSD-FALSE-desktop', 6, 0.0)
# (u'Firefox-OpenBSD-FALSE-desktop', 2, 0.0)
# (u'Firefox-SunOS-FALSE-desktop', 1, 0.0)
# (u'Internet Explorer-Windows-FALSE-desktop', 17798, 424234.18361613667)
# (u'Internet Explorer-Windows-FALSE-mobile', 4, 0.0)
# (u'Internet Explorer-Windows-TRUE-mobile', 895, 736055.8659217877)
# (u'Internet Explorer-Windows-TRUE-tablet', 394, 117411.16751269036)
# (u'Internet Explorer-Windows-TRUE-desktop', 4, 0.0)
# (u'Internet Explorer-Windows Phone-TRUE-mobile', 269, 0.0)
# (u'Internet Explorer-Windows Phone-TRUE-tablet', 1, 0.0)
# (u'Internet Explorer-Xbox-FALSE-desktop', 7, 0.0)
# (u'Internet Explorer-Macintosh-FALSE-desktop', 2, 0.0)
# (u'Internet Explorer-(not set)-FALSE-desktop', 1, 0.0)
# (u'Edge-Windows-FALSE-desktop', 9832, 659374.4914564687)
# (u'Edge-Windows-FALSE-mobile', 1, 0.0)
# (u'Edge-Windows-TRUE-mobile', 305, 0.0)
# (u'Edge-Windows-TRUE-tablet', 5, 0.0)
# (u'Edge-Windows-TRUE-desktop', 1, 0.0)
# (u'Edge-Xbox-FALSE-desktop', 59, 0.0)
# (u'Edge-(not set)-FALSE-desktop', 2, 0.0)
# (u'Android Webview-Android-TRUE-mobile', 7286, 12610.485863299478)
# (u'Android Webview-Android-TRUE-tablet', 575, 39947.82608695652)
# (u'Android Webview-Android-FALSE-desktop', 4, 0.0)
# (u'Safari (in-app)-iOS-TRUE-mobile', 5905, 21808.636748518205)
# (u'Safari (in-app)-iOS-TRUE-tablet', 939, 26613.41853035144)
# (u'Safari (in-app)-iOS-FALSE-desktop', 5, 0.0)
# (u'Safari (in-app)-iOS-FALSE-mobile', 1, 0.0)
# (u'Opera Mini-(not set)-TRUE-mobile', 4077, 0.0)
# (u'Opera Mini-(not set)-TRUE-tablet', 34, 0.0)
# (u'Opera Mini-Android-TRUE-mobile', 1687, 0.0)
# (u'Opera Mini-Samsung-TRUE-mobile', 280, 0.0)
# (u'Opera Mini-BlackBerry-TRUE-mobile', 31, 0.0)
# (u'Opera Mini-Windows Phone-TRUE-mobile', 27, 0.0)
# (u'Opera Mini-iOS-TRUE-mobile', 2, 0.0)
# (u'Opera Mini-iOS-TRUE-tablet', 1, 0.0)
# (u'Opera-Windows-FALSE-desktop', 4706, 36219.71950701233)
# (u'Opera-Android-TRUE-mobile', 549, 0.0)
# (u'Opera-Android-TRUE-tablet', 39, 0.0)
# (u'Opera-Android-TRUE-desktop', 2, 0.0)
# (u'Opera-Macintosh-FALSE-desktop', 210, 213809.52380952382)
# (u'Opera-Linux-FALSE-desktop', 127, 0.0)
# (u'Opera-Linux-FALSE-mobile', 10, 0.0)
# (u'UC Browser-Android-TRUE-mobile', 1469, 0.0)
# (u'UC Browser-Android-TRUE-tablet', 25, 0.0)
# (u'UC Browser-Android-TRUE-desktop', 1, 0.0)
# (u'UC Browser-Linux-FALSE-desktop', 846, 0.0)
# (u'UC Browser-Linux-FALSE-mobile', 1, 0.0)
# (u'UC Browser-iOS-TRUE-mobile', 56, 0.0)
# (u'UC Browser-iOS-TRUE-tablet', 10, 0.0)
# (u'UC Browser-Windows-FALSE-desktop', 8, 0.0)
# (u'UC Browser-Windows-TRUE-tablet', 3, 0.0)
# (u'UC Browser-Windows Phone-TRUE-mobile', 7, 0.0)
# (u'UC Browser-(not set)-FALSE-desktop', 1, 0.0)
# (u'Chrome-Windows-FALSE-desktop', 284522, 1041826.2208194797)
# (u'Chrome-Windows-FALSE-mobile', 7, 0.0)
# (u'Chrome-Windows-TRUE-mobile', 3, 0.0)
# (u'Chrome-Windows-TRUE-desktop', 1, 0.0)
# (u'Chrome-Macintosh-FALSE-desktop', 156187, 5242908.820836562)
# (u'Chrome-Macintosh-FALSE-mobile', 7, 0.0)
# (u'Chrome-Macintosh-TRUE-mobile', 7, 0.0)
# (u'Chrome-Android-TRUE-mobile', 101953, 322134.512961855)
# (u'Chrome-Android-TRUE-tablet', 7810, 419001.2804097311)
# (u'Chrome-Android-TRUE-desktop', 76, 460394.7368421053)
# (u'Chrome-Android-FALSE-desktop', 4, 0.0)
# (u'Chrome-Linux-FALSE-desktop', 30966, 1415475.3600723373)
# (u'Chrome-Linux-FALSE-mobile', 91, 27802.197802197803)
# (u'Chrome-Linux-FALSE-tablet', 10, 0.0)
# (u'Chrome-Linux-TRUE-mobile', 10, 0.0)
# (u'Chrome-Linux-TRUE-desktop', 1, 0.0)
# (u'Chrome-Linux-TRUE-tablet', 1, 0.0)
# (u'Chrome-Chrome OS-FALSE-desktop', 26337, 6984005.391654327)
# (u'Chrome-iOS-TRUE-mobile', 9680, 328922.52066115703)
# (u'Chrome-iOS-TRUE-tablet', 2533, 277319.3841294907)
# (u'Chrome-iOS-TRUE-desktop', 6, 0.0)
# (u'Chrome-iOS-FALSE-desktop', 1, 0.0)
# (u'Chrome-(not set)-FALSE-desktop', 145, 0.0)
# (u'Chrome-FreeBSD-FALSE-desktop', 3, 0.0)
# (u'Chrome-BlackBerry-TRUE-mobile', 2, 0.0)
# (u'Chrome-Windows Phone-TRUE-mobile', 1, 0.0)
# (u'Safari-Macintosh-FALSE-desktop', 92137, 371667.9509860317)
# (u'Safari-Macintosh-FALSE-mobile', 25, 0.0)
# (u'Safari-Macintosh-FALSE-tablet', 4, 0.0)
# (u'Safari-iOS-TRUE-mobile', 71029, 180270.45291359868)
# (u'Safari-iOS-TRUE-tablet', 17446, 305071.6496618136)
# (u'Safari-iOS-TRUE-desktop', 15, 0.0)
# (u'Safari-iOS-FALSE-desktop', 2, 0.0)
# (u'Safari-Windows Phone-TRUE-mobile', 911, 28979.14379802415)
# (u'Safari-Linux-FALSE-desktop', 650, 0.0)
# (u'Safari-Windows-FALSE-desktop', 25, 0.0)
# (u'Safari-(not set)-FALSE-desktop', 1, 0.0)
# (u'Firefox-Windows-FALSE-desktop', 28346, 3033277.0055739786)
# (u'Firefox-Macintosh-FALSE-desktop', 5256, 611171.9939117199)
# (u'Firefox-Linux-FALSE-desktop', 2227, 34243.37674000898)
# (u'Firefox-Android-TRUE-mobile', 1136, 40906.69014084507)
# (u'Firefox-Android-TRUE-tablet', 6, 0.0)
# (u'Firefox-Firefox OS-TRUE-mobile', 87, 0.0)
# (u'Firefox-Firefox OS-TRUE-tablet', 2, 0.0)
# (u'Firefox-FreeBSD-FALSE-desktop', 6, 0.0)
# (u'Firefox-OpenBSD-FALSE-desktop', 2, 0.0)
# (u'Firefox-SunOS-FALSE-desktop', 1, 0.0)
# (u'Internet Explorer-Windows-FALSE-desktop', 17798, 424234.18361613667)
# (u'Internet Explorer-Windows-FALSE-mobile', 4, 0.0)
# (u'Internet Explorer-Windows-TRUE-mobile', 895, 736055.8659217877)
# (u'Internet Explorer-Windows-TRUE-tablet', 394, 117411.16751269036)
# (u'Internet Explorer-Windows-TRUE-desktop', 4, 0.0)
# (u'Internet Explorer-Windows Phone-TRUE-mobile', 269, 0.0)
# (u'Internet Explorer-Windows Phone-TRUE-tablet', 1, 0.0)
# (u'Internet Explorer-Xbox-FALSE-desktop', 7, 0.0)
# (u'Internet Explorer-Macintosh-FALSE-desktop', 2, 0.0)
# (u'Internet Explorer-(not set)-FALSE-desktop', 1, 0.0)
# (u'Edge-Windows-FALSE-desktop', 9832, 659374.4914564687)
# (u'Edge-Windows-FALSE-mobile', 1, 0.0)
# (u'Edge-Windows-TRUE-mobile', 305, 0.0)
# (u'Edge-Windows-TRUE-tablet', 5, 0.0)
# (u'Edge-Windows-TRUE-desktop', 1, 0.0)
# (u'Edge-Xbox-FALSE-desktop', 59, 0.0)
# (u'Edge-(not set)-FALSE-desktop', 2, 0.0)
# (u'Android Webview-Android-TRUE-mobile', 7286, 12610.485863299478)
# (u'Android Webview-Android-TRUE-tablet', 575, 39947.82608695652)
# (u'Android Webview-Android-FALSE-desktop', 4, 0.0)
# (u'Safari (in-app)-iOS-TRUE-mobile', 5905, 21808.636748518205)
# (u'Safari (in-app)-iOS-TRUE-tablet', 939, 26613.41853035144)
# (u'Safari (in-app)-iOS-FALSE-desktop', 5, 0.0)
# (u'Safari (in-app)-iOS-FALSE-mobile', 1, 0.0)
# (u'Opera Mini-(not set)-TRUE-mobile', 4077, 0.0)
# (u'Opera Mini-(not set)-TRUE-tablet', 34, 0.0)
# (u'Opera Mini-Android-TRUE-mobile', 1687, 0.0)
# (u'Opera Mini-Samsung-TRUE-mobile', 280, 0.0)
# (u'Opera Mini-BlackBerry-TRUE-mobile', 31, 0.0)
# (u'Opera Mini-Windows Phone-TRUE-mobile', 27, 0.0)
# (u'Opera Mini-iOS-TRUE-mobile', 2, 0.0)
# (u'Opera Mini-iOS-TRUE-tablet', 1, 0.0)
# (u'Opera-Windows-FALSE-desktop', 4706, 36219.71950701233)
# (u'Opera-Android-TRUE-mobile', 549, 0.0)
# (u'Opera-Android-TRUE-tablet', 39, 0.0)
# (u'Opera-Android-TRUE-desktop', 2, 0.0)
# (u'Opera-Macintosh-FALSE-desktop', 210, 213809.52380952382)
# (u'Opera-Linux-FALSE-desktop', 127, 0.0)
# (u'Opera-Linux-FALSE-mobile', 10, 0.0)
# (u'UC Browser-Android-TRUE-mobile', 1469, 0.0)
# (u'UC Browser-Android-TRUE-tablet', 25, 0.0)
# (u'UC Browser-Android-TRUE-desktop', 1, 0.0)
# (u'UC Browser-Linux-FALSE-desktop', 846, 0.0)
# (u'UC Browser-Linux-FALSE-mobile', 1, 0.0)
# (u'UC Browser-iOS-TRUE-mobile', 56, 0.0)
# (u'UC Browser-iOS-TRUE-tablet', 10, 0.0)
# (u'UC Browser-Windows-FALSE-desktop', 8, 0.0)
# (u'UC Browser-Windows-TRUE-tablet', 3, 0.0)
# (u'UC Browser-Windows Phone-TRUE-mobile', 7, 0.0)
# (u'UC Browser-(not set)-FALSE-desktop', 1, 0.0)
# (u'Chrome-Windows-FALSE-desktop', 284522, 1041826.2208194797)
# (u'Chrome-Windows-FALSE-mobile', 7, 0.0)
# (u'Chrome-Windows-TRUE-mobile', 3, 0.0)
# (u'Chrome-Windows-TRUE-desktop', 1, 0.0)
# (u'Chrome-Macintosh-FALSE-desktop', 156187, 5242908.820836562)
# (u'Chrome-Macintosh-FALSE-mobile', 7, 0.0)
# (u'Chrome-Macintosh-TRUE-mobile', 7, 0.0)
# (u'Chrome-Android-TRUE-mobile', 101953, 322134.512961855)
# (u'Chrome-Android-TRUE-tablet', 7810, 419001.2804097311)
# (u'Chrome-Android-TRUE-desktop', 76, 460394.7368421053)
# (u'Chrome-Android-FALSE-desktop', 4, 0.0)
# (u'Chrome-Linux-FALSE-desktop', 30966, 1415475.3600723373)
# (u'Chrome-Linux-FALSE-mobile', 91, 27802.197802197803)
# (u'Chrome-Linux-FALSE-tablet', 10, 0.0)
# (u'Chrome-Linux-TRUE-mobile', 10, 0.0)
# (u'Chrome-Linux-TRUE-desktop', 1, 0.0)
# (u'Chrome-Linux-TRUE-tablet', 1, 0.0)
# (u'Chrome-Chrome OS-FALSE-desktop', 26337, 6984005.391654327)
# (u'Chrome-iOS-TRUE-mobile', 9680, 328922.52066115703)
# (u'Chrome-iOS-TRUE-tablet', 2533, 277319.3841294907)
# (u'Chrome-iOS-TRUE-desktop', 6, 0.0)
# (u'Chrome-iOS-FALSE-desktop', 1, 0.0)
# (u'Chrome-(not set)-FALSE-desktop', 145, 0.0)
# (u'Chrome-FreeBSD-FALSE-desktop', 3, 0.0)
# (u'Chrome-BlackBerry-TRUE-mobile', 2, 0.0)
# (u'Chrome-Windows Phone-TRUE-mobile', 1, 0.0)
# (u'Safari-Macintosh-FALSE-desktop', 92137, 371667.9509860317)
# (u'Safari-Macintosh-FALSE-mobile', 25, 0.0)
# (u'Safari-Macintosh-FALSE-tablet', 4, 0.0)
# (u'Safari-iOS-TRUE-mobile', 71029, 180270.45291359868)
# (u'Safari-iOS-TRUE-tablet', 17446, 305071.6496618136)
# (u'Safari-iOS-TRUE-desktop', 15, 0.0)
# (u'Safari-iOS-FALSE-desktop', 2, 0.0)
# (u'Safari-Windows Phone-TRUE-mobile', 911, 28979.14379802415)
# (u'Safari-Linux-FALSE-desktop', 650, 0.0)
# (u'Safari-Windows-FALSE-desktop', 25, 0.0)
# (u'Safari-(not set)-FALSE-desktop', 1, 0.0)
# (u'Firefox-Windows-FALSE-desktop', 28346, 3033277.0055739786)
# (u'Firefox-Macintosh-FALSE-desktop', 5256, 611171.9939117199)
# (u'Firefox-Linux-FALSE-desktop', 2227, 34243.37674000898)
# (u'Firefox-Android-TRUE-mobile', 1136, 40906.69014084507)
# (u'Firefox-Android-TRUE-tablet', 6, 0.0)
# (u'Firefox-Firefox OS-TRUE-mobile', 87, 0.0)
# (u'Firefox-Firefox OS-TRUE-tablet', 2, 0.0)
# (u'Firefox-FreeBSD-FALSE-desktop', 6, 0.0)
# (u'Firefox-OpenBSD-FALSE-desktop', 2, 0.0)
# (u'Firefox-SunOS-FALSE-desktop', 1, 0.0)
# (u'Internet Explorer-Windows-FALSE-desktop', 17798, 424234.18361613667)
# (u'Internet Explorer-Windows-FALSE-mobile', 4, 0.0)
# (u'Internet Explorer-Windows-TRUE-mobile', 895, 736055.8659217877)
# (u'Internet Explorer-Windows-TRUE-tablet', 394, 117411.16751269036)
# (u'Internet Explorer-Windows-TRUE-desktop', 4, 0.0)
# (u'Internet Explorer-Windows Phone-TRUE-mobile', 269, 0.0)
# (u'Internet Explorer-Windows Phone-TRUE-tablet', 1, 0.0)
# (u'Internet Explorer-Xbox-FALSE-desktop', 7, 0.0)
# (u'Internet Explorer-Macintosh-FALSE-desktop', 2, 0.0)
# (u'Internet Explorer-(not set)-FALSE-desktop', 1, 0.0)
# (u'Edge-Windows-FALSE-desktop', 9832, 659374.4914564687)
# (u'Edge-Windows-FALSE-mobile', 1, 0.0)
# (u'Edge-Windows-TRUE-mobile', 305, 0.0)
# (u'Edge-Windows-TRUE-tablet', 5, 0.0)
# (u'Edge-Windows-TRUE-desktop', 1, 0.0)
# (u'Edge-Xbox-FALSE-desktop', 59, 0.0)
# (u'Edge-(not set)-FALSE-desktop', 2, 0.0)
# (u'Android Webview-Android-TRUE-mobile', 7286, 12610.485863299478)
# (u'Android Webview-Android-TRUE-tablet', 575, 39947.82608695652)
# (u'Android Webview-Android-FALSE-desktop', 4, 0.0)
# (u'Safari (in-app)-iOS-TRUE-mobile', 5905, 21808.636748518205)
# (u'Safari (in-app)-iOS-TRUE-tablet', 939, 26613.41853035144)
# (u'Safari (in-app)-iOS-FALSE-desktop', 5, 0.0)
# (u'Safari (in-app)-iOS-FALSE-mobile', 1, 0.0)
# (u'Opera Mini-(not set)-TRUE-mobile', 4077, 0.0)
# (u'Opera Mini-(not set)-TRUE-tablet', 34, 0.0)
# (u'Opera Mini-Android-TRUE-mobile', 1687, 0.0)
# (u'Opera Mini-Samsung-TRUE-mobile', 280, 0.0)
# (u'Opera Mini-BlackBerry-TRUE-mobile', 31, 0.0)
# (u'Opera Mini-Windows Phone-TRUE-mobile', 27, 0.0)
# (u'Opera Mini-iOS-TRUE-mobile', 2, 0.0)
# (u'Opera Mini-iOS-TRUE-tablet', 1, 0.0)
# (u'Opera-Windows-FALSE-desktop', 4706, 36219.71950701233)
# (u'Opera-Android-TRUE-mobile', 549, 0.0)
# (u'Opera-Android-TRUE-tablet', 39, 0.0)
# (u'Opera-Android-TRUE-desktop', 2, 0.0)
# (u'Opera-Macintosh-FALSE-desktop', 210, 213809.52380952382)
# (u'Opera-Linux-FALSE-desktop', 127, 0.0)
# (u'Opera-Linux-FALSE-mobile', 10, 0.0)
# (u'UC Browser-Android-TRUE-mobile', 1469, 0.0)
# (u'UC Browser-Android-TRUE-tablet', 25, 0.0)
# (u'UC Browser-Android-TRUE-desktop', 1, 0.0)
# (u'UC Browser-Linux-FALSE-desktop', 846, 0.0)
# (u'UC Browser-Linux-FALSE-mobile', 1, 0.0)
# (u'UC Browser-iOS-TRUE-mobile', 56, 0.0)
# (u'UC Browser-iOS-TRUE-tablet', 10, 0.0)
# (u'UC Browser-Windows-FALSE-desktop', 8, 0.0)
# (u'UC Browser-Windows-TRUE-tablet', 3, 0.0)
# (u'UC Browser-Windows Phone-TRUE-mobile', 7, 0.0)
# (u'UC Browser-(not set)-FALSE-desktop', 1, 0.0)

# %%
# グラフ化
x=[]
y=[]
ylabel=[]

for i in range(len(restmp)):
    x.append(len(restmp)-i)
    y.append(restmp[i]['aggs_avg_revenue']['value'])
    ylabel.append(restmp[i]['key'])
    
pyplot.barh(x,y,align="center")
pyplot.yticks(x,ylabel)
pyplot.show()
# Out:
# NameErrorTraceback (most recent call last)
# <ipython-input-5-c10b1ca2512f> in <module>()
#       4 ylabel=[]
#       5
# ----> 6 for i in range(len(restmp)):
#       7     x.append(len(restmp)-i)
#       8     y.append(restmp[i]['aggs_avg_revenue']['value'])
#
# NameError: name 'restmp' is not defined

# %%
# 横棒グラフの部品化：データ件数/カテゴリごとのrevenue平均
def showBarGraph(field):
    body = {
        "size":0,
        "aggs":{
            "aggs_field":{
                "terms":{
                    "field":field+".keyword",
                    "order":{"_count":"desc"}
                },
                "aggs":{
                    "aggs_avg_revenue":{
                        "avg":{"field":"transactionRevenue"}
                    }
                }
            }
        }
    }
    #print(body)
    
    esRes=escon.search(index='gacrp_index',body=body)
    data=esRes['aggregations']['aggs_field']['buckets']

    graph_x=[]
    graph_y=[]
    graph_ylabel=[]

    graph_avgx=[]
    graph_avgy=[]
    graph_avgylabel=[]

    for i in range(len(data)):
        graph_x.append(len(data)-i)
        graph_y.append(data[i]['doc_count'])
        graph_ylabel.append(data[i]['key'])
    
    pyplot.barh(graph_x,graph_y,align="center")
    pyplot.yticks(graph_x,graph_ylabel)
    pyplot.title(field+" count")
    pyplot.show()

    for i in range(len(data)):
        graph_avgx.append(len(data)-i)
        graph_avgy.append(data[i]['aggs_avg_revenue']['value'])
        graph_avgylabel.append(data[i]['key'])
    
    pyplot.barh(graph_avgx,graph_avgy,align="center")
    pyplot.yticks(graph_avgx,graph_avgylabel)
    pyplot.title(field+" average transactionevenue")
    pyplot.show()

    
    return

# %%
showBarGraph("channelGrouping")

# %%
showBarGraph("browser")

# %%
showBarGraph("isMobile")

# %%
showBarGraph("continent")

# %%
showBarGraph("country")

# %%
showBarGraph("keyword")

# %%
showBarGraph("isTrueDirect")

# %%
showBarGraph("networkDomain")
#  networkLocation is not available

# %%
fields=["channelGrouping","visitNumber","browser","operatingSystem","isMobile","deviceCategory","continent","subContinent","country","region","metro","city","networkDomain","visits","hits","pageviews","bounces","newVisits","transactionRevenue","campaign","source","medium","keyword","isTrueDirect","referralPath","adContent","campaignCode","adwordsClickInfo.criteriaParameters","adwordsClickInfo.page","adwordsClickInfo.slot","adwordsClickInfo.gclId","adwordsClickInfo.adNetworkType","adwordsClickInfo.isVideoAd"]
# socialEngagementType,browserVersion,browserSize,"operatingSystemVersion","mobileDeviceBranding",,"mobileDeviceModel","mobileInputSelector","mobileDeviceInfo","mobileDeviceMarketingName","flashVersion","language","screenColors","screenResolution","cityId","latitude","longitude","networkLocation"
for field in fields:
    showBarGraph(field)
