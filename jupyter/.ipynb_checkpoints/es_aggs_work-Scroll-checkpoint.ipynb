# %%
#前処理後のindex作るための処理
import os
import elasticsearch as es
import math
import numpy as np
from itertools import chain
import sys
import tensorflow as tf

ES_HOST = "localhost"
escon = es.Elasticsearch(ES_HOST, port=9200)
GACRP_HOME=os.environ['GACRP_HOME']

# %%
data=[]
ans = []

# 元データ取得
es_size=10000
es_s_time='2m'
body = {
    "_source":["channelGrouping","visitNumber","isMobile","country","hits","bounces","newVisits","source","medium","isTrueDirect","transactionRevenue"],
    "query": {
      "match_all": {}
    }
  }
  
res=escon.search(index='gacrp_index',body=body,scroll=es_s_time,size=es_size)
es_s_id=res['_scroll_id']
es_s_size=len(res["hits"]["hits"])

# %%
def setByScroll(res,data,ans):
    for i in range(len(res["hits"]["hits"])):
        row=res["hits"]["hits"][i]["_source"]
        rec=[]

        if row['channelGrouping']=='Display':
            col_channelGrouping=1
        elif row['channelGrouping']=='Social':
            col_channelGrouping=2
        else:
            col_channelGrouping=0
        oneHot_col_channelGrouping=np.eye(2+1)[col_channelGrouping]
        
        col_visitNumber=min(int(row['visitNumber']),5)/5.0 

        if row['isMobile']=="TRUE":
            col_isMobile=1
        else:
            col_isMobile=0

        if row['country']=="United States":
            col_country =1
        elif row['country']=="Canada":
            col_country =2
        elif row['country']=="Japan":
            col_country=3
        else:
            col_country=0
        oneHot_col_country=np.eye(3+1)[col_country]
    
        col_hits=math.log10(int(row['hits'])*1.0)
    
        if row['bounces']=="1":
            col_bounces=1
        else:
            col_bounces=0

        if row['newVisits']== "1":
            col_newVisits=1
        else:
            col_newVisits=0
    
        if row['source']=="mail.googleplex.com" or row['source']=="dfa":
            col_source =1
        elif row['source']=="(direct)":
            col_source=2
        else:
            col_source=0
        oneHot_col_source=np.eye(2+1)[col_source]
        
        if row['medium']=="cpm":
            col_medium=1
        else:
            col_medium=0
        oneHot_col_medium=np.eye(1+1)[col_medium]
    
        if row['isTrueDirect']=="1":
            col_isTrueDirect=1
        else:
            col_isTrueDirect=0
    
        revenue = math.log(int(row['transactionRevenue'])+1)
    
        l=[oneHot_col_channelGrouping,[col_visitNumber],[col_isMobile],oneHot_col_country,[col_hits],[col_bounces],[col_newVisits],oneHot_col_source,oneHot_col_medium,[col_isTrueDirect]]
        data.append(list(chain.from_iterable(l)))
        ans.append(revenue)
    
    return(data,ans)

# %%
while(es_s_size>0):
    data,ans=setByScroll(res,data,ans)
    res=escon.scroll(scroll_id=es_s_id,scroll=es_s_time)
    es_s_id=res['_scroll_id']
    es_s_size=len(res["hits"]["hits"])
    #print(len(data),len(ans))
# Out:
# (10000, 10000)
# (20000, 20000)
# (30000, 30000)
# (40000, 40000)
# (50000, 50000)
# (60000, 60000)
# (70000, 70000)
# (80000, 80000)
# (90000, 90000)
# (100000, 100000)
# (110000, 110000)
# (120000, 120000)
# (130000, 130000)
# (140000, 140000)
# (150000, 150000)
# (160000, 160000)
# (170000, 170000)
# (180000, 180000)
# (190000, 190000)
# (200000, 200000)
# (210000, 210000)
# (220000, 220000)
# (230000, 230000)
# (240000, 240000)
# (250000, 250000)
# (260000, 260000)
# (270000, 270000)
# (280000, 280000)
# (290000, 290000)
# (300000, 300000)
# (310000, 310000)
# (320000, 320000)
# (330000, 330000)
# (340000, 340000)
# (350000, 350000)
# (360000, 360000)
# (370000, 370000)
# (380000, 380000)
# (390000, 390000)
# (400000, 400000)
# (410000, 410000)
# (420000, 420000)
# (430000, 430000)
# (440000, 440000)
# (450000, 450000)
# (460000, 460000)
# (470000, 470000)
# (480000, 480000)
# (490000, 490000)
# (500000, 500000)
# (510000, 510000)
# (520000, 520000)
# (530000, 530000)
# (540000, 540000)
# (550000, 550000)
# (560000, 560000)
# (570000, 570000)
# (580000, 580000)
# (590000, 590000)
# (600000, 600000)
# (610000, 610000)
# (620000, 620000)
# (630000, 630000)
# (640000, 640000)
# (650000, 650000)
# (660000, 660000)
# (670000, 670000)
# (680000, 680000)
# (690000, 690000)
# (700000, 700000)
# (710000, 710000)
# (720000, 720000)
# (730000, 730000)
# (740000, 740000)
# (750000, 750000)
# (760000, 760000)
# (770000, 770000)
# (780000, 780000)
# (790000, 790000)
# (800000, 800000)
# (810000, 810000)
# (820000, 820000)
# (830000, 830000)
# (840000, 840000)
# (850000, 850000)
# (860000, 860000)
# (870000, 870000)
# (880000, 880000)
# (890000, 890000)
# (900000, 900000)
# (903653, 903653)

# %%
#print(data[0],ans[0])
#inputData=tf.transpose(data)
num_elements=18
num_rows=len(data)
inputData=np.reshape(data,(num_rows,num_elements))
#print("data",data[0])
#print("inputData",inputData[0],inputData.shape)
inputAns=np.reshape(ans,(num_rows,1))
#print("AnsShape",inputAns.shape)
#inputAns=ans
x =tf.placeholder("float",[None,num_elements])
y_=tf.placeholder("float",[None,1])

a=tf.Variable( tf.ones([18,1]),name="weights")
b=tf.Variable(tf.zeros([1,1]),name="intercept")
print(x.shape)
#y=tf.matmul(tf.transpose(a),x)+b
#y=tf.matmul(a,x)+b
y=tf.matmul(a,x)

init = tf.global_variables_initializer()
loss = tf.reduce_sum(tf.square(y_-y))
train_step=tf.train.GradientDescentOptimizer(0.01).minimize(loss)
# Out:
# (?, 18)

# %%
with tf.Session() as sess:
    sess.run(init)
    print('初期状態')
    print('誤差' + str(sess.run(loss, feed_dict={x: inputData[0:1], y_: inputAns[0:1]})))
    #print("weigths: %f, intercept: %f" % (sess.run(a), sess.run(b) ))
    print("weigths:",sum(sess.run(a)),"intercept:",sess.run(b) )
    
    for step in range(100000):
        sess.run(train_step, feed_dict={x: inputData[step+1:step+1+1], y_: inputAns[step+1:step+1+1]})
        if (step+1) % 2000 == 0:
            print('\nStep: %s' % (step+1))
            print("input:",inputAns[step+1:step+1+1])
            print('誤差' + str(sess.run(loss, feed_dict={x: inputData[step+1:step+1+1], y_: inputAns[step+1:step+1+1]})))
            #print("weights:",sum(sess.run(a)), " intercept: %f" % ( sess.run(b)))
            print("weights:",sess.run(a), " intercept: %f" % ( sess.run(b)))
# Out:
# 初期状態
# 誤差108.72
# ('weigths:', array([ 18.], dtype=float32), 'intercept:', array([[ 0.]], dtype=float32))
#
# Step: 2000
# ('input:', array([[ 0.]]))
# 誤差0.0
# ('weights:', array([[  1.56717603e-26],
#        [  1.56717603e-26],
#        [  1.56717603e-26],
#        [  1.56717603e-26],
#        [  1.56717603e-26],
#        [  1.56717603e-26],
#        [  1.56717603e-26],
#        [  1.56717603e-26],
#        [  1.56717603e-26],
#        [  1.56717603e-26],
#        [  1.56717603e-26],
#        [  1.56717603e-26],
#        [  1.56717603e-26],
#        [  1.56717603e-26],
#        [  1.56717603e-26],
#        [  1.56717603e-26],
#        [  1.56717603e-26],
#        [  1.56717603e-26]], dtype=float32), ' intercept: 0.000000')
#
# Step: 4000
# ('input:', array([[ 0.]]))
# 誤差5.00451e-26
# ('weights:', array([[  2.14548821e-14],
#        [  2.14548821e-14],
#        [  2.14548821e-14],
#        [  2.14548821e-14],
#        [  2.14548821e-14],
#        [  2.14548821e-14],
#        [  2.14548821e-14],
#        [  2.14548821e-14],
#        [  2.14548821e-14],
#        [  2.14548821e-14],
#        [  2.14548821e-14],
#        [  2.14548821e-14],
#        [  2.14548821e-14],
#        [  2.14548821e-14],
#        [  2.14548821e-14],
#        [  2.14548821e-14],
#        [  2.14548821e-14],
#        [  2.14548821e-14]], dtype=float32), ' intercept: 0.000000')
#
# Step: 6000
# ('input:', array([[ 0.]]))
# 誤差0.000587548
# ('weights:', array([[ 0.0023247],
#        [ 0.0023247],
#        [ 0.0023247],
#        [ 0.0023247],
#        [ 0.0023247],
#        [ 0.0023247],
#        [ 0.0023247],
#        [ 0.0023247],
#        [ 0.0023247],
#        [ 0.0023247],
#        [ 0.0023247],
#        [ 0.0023247],
#        [ 0.0023247],
#        [ 0.0023247],
#        [ 0.0023247],
#        [ 0.0023247],
#        [ 0.0023247],
#        [ 0.0023247]], dtype=float32), ' intercept: 0.000000')
#
# Step: 8000
# ('input:', array([[ 0.]]))
# 誤差2.64016e-24
# ('weights:', array([[  1.69743627e-13],
#        [  1.69743627e-13],
#        [  1.69743627e-13],
#        [  1.69743627e-13],
#        [  1.69743627e-13],
#        [  1.69743627e-13],
#        [  1.69743627e-13],
#        [  1.69743627e-13],
#        [  1.69743627e-13],
#        [  1.69743627e-13],
#        [  1.69743627e-13],
#        [  1.69743627e-13],
#        [  1.69743627e-13],
#        [  1.69743627e-13],
#        [  1.69743627e-13],
#        [  1.69743627e-13],
#        [  1.69743627e-13],
#        [  1.69743627e-13]], dtype=float32), ' intercept: 0.000000')
#
# Step: 10000
# ('input:', array([[ 0.]]))
# 誤差1.93718e-08
# ('weights:', array([[  1.33484318e-05],
#        [  1.33484318e-05],
#        [  1.33484318e-05],
#        [  1.33484318e-05],
#        [  1.33484318e-05],
#        [  1.33484318e-05],
#        [  1.33484318e-05],
#        [  1.33484318e-05],
#        [  1.33484318e-05],
#        [  1.33484318e-05],
#        [  1.33484318e-05],
#        [  1.33484318e-05],
#        [  1.33484318e-05],
#        [  1.33484318e-05],
#        [  1.33484318e-05],
#        [  1.33484318e-05],
#        [  1.33484318e-05],
#        [  1.33484318e-05]], dtype=float32), ' intercept: 0.000000')
#
# Step: 12000
# ('input:', array([[ 0.]]))
# 誤差0.130203
# ('weights:', array([[ 0.03744112],
#        [ 0.03744112],
#        [ 0.03744112],
#        [ 0.03744112],
#        [ 0.03744112],
#        [ 0.03744112],
#        [ 0.03744112],
#        [ 0.03744112],
#        [ 0.03744112],
#        [ 0.03744112],
#        [ 0.03744112],
#        [ 0.03744112],
#        [ 0.03744112],
#        [ 0.03744112],
#        [ 0.03744112],
#        [ 0.03744112],
#        [ 0.03744112],
#        [ 0.03744112]], dtype=float32), ' intercept: 0.000000')
#
# Step: 14000
# ('input:', array([[ 0.]]))
# 誤差8.18853e-21
# ('weights:', array([[  9.41633577e-12],
#        [  9.41633577e-12],
#        [  9.41633577e-12],
#        [  9.41633577e-12],
#        [  9.41633577e-12],
#        [  9.41633577e-12],
#        [  9.41633577e-12],
#        [  9.41633577e-12],
#        [  9.41633577e-12],
#        [  9.41633577e-12],
#        [  9.41633577e-12],
#        [  9.41633577e-12],
#        [  9.41633577e-12],
#        [  9.41633577e-12],
#        [  9.41633577e-12],
#        [  9.41633577e-12],
#        [  9.41633577e-12],
#        [  9.41633577e-12]], dtype=float32), ' intercept: 0.000000')
#
# Step: 16000
# ('input:', array([[ 0.]]))
# 誤差0.0
# ('weights:', array([[  5.49893870e-33],
#        [  5.49893870e-33],
#        [  5.49893870e-33],
#        [  5.49893870e-33],
#        [  5.49893870e-33],
#        [  5.49893870e-33],
#        [  5.49893870e-33],
#        [  5.49893870e-33],
#        [  5.49893870e-33],
#        [  5.49893870e-33],
#        [  5.49893870e-33],
#        [  5.49893870e-33],
#        [  5.49893870e-33],
#        [  5.49893870e-33],
#        [  5.49893870e-33],
#        [  5.49893870e-33],
#        [  5.49893870e-33],
#        [  5.49893870e-33]], dtype=float32), ' intercept: 0.000000')
#
# Step: 18000
# ('input:', array([[ 17.84068368]]))
# 誤差93135.5
# ('weights:', array([[ 2.59545541],
#        [ 2.59545541],
#        [ 2.59545541],
#        [ 2.59545541],
#        [ 2.59545541],
#        [ 2.59545541],
#        [ 2.59545541],
#        [ 2.59545541],
#        [ 2.59545541],
#        [ 2.59545541],
#        [ 2.59545541],
#        [ 2.59545541],
#        [ 2.59545541],
#        [ 2.59545541],
#        [ 2.59545541],
#        [ 2.59545541],
#        [ 2.59545541],
#        [ 2.59545541]], dtype=float32), ' intercept: 0.000000')
#
# Step: 20000
# ('input:', array([[ 0.]]))
# 誤差2.74582e-36
# ('weights:', array([[  1.74668660e-19],
#        [  1.74668660e-19],
#        [  1.74668660e-19],
#        [  1.74668660e-19],
#        [  1.74668660e-19],
#        [  1.74668660e-19],
#        [  1.74668660e-19],
#        [  1.74668660e-19],
#        [  1.74668660e-19],
#        [  1.74668660e-19],
#        [  1.74668660e-19],
#        [  1.74668660e-19],
#        [  1.74668660e-19],
#        [  1.74668660e-19],
#        [  1.74668660e-19],
#        [  1.74668660e-19],
#        [  1.74668660e-19],
#        [  1.74668660e-19]], dtype=float32), ' intercept: 0.000000')
#
# Step: 22000
# ('input:', array([[ 0.]]))
# 誤差913.327
# ('weights:', array([[ 2.52623177],
#        [ 2.52623177],
#        [ 2.52623177],
#        [ 2.52623177],
#        [ 2.52623177],
#        [ 2.52623177],
#        [ 2.52623177],
#        [ 2.52623177],
#        [ 2.52623177],
#        [ 2.52623177],
#        [ 2.52623177],
#        [ 2.52623177],
#        [ 2.52623177],
#        [ 2.52623177],
#        [ 2.52623177],
#        [ 2.52623177],
#        [ 2.52623177],
#        [ 2.52623177]], dtype=float32), ' intercept: 0.000000')
#
# Step: 24000
# ('input:', array([[ 0.]]))
# 誤差34.6447
# ('weights:', array([[ 0.6124872],
#        [ 0.6124872],
#        [ 0.6124872],
#        [ 0.6124872],
#        [ 0.6124872],
#        [ 0.6124872],
#        [ 0.6124872],
#        [ 0.6124872],
#        [ 0.6124872],
#        [ 0.6124872],
#        [ 0.6124872],
#        [ 0.6124872],
#        [ 0.6124872],
#        [ 0.6124872],
#        [ 0.6124872],
#        [ 0.6124872],
#        [ 0.6124872],
#        [ 0.6124872]], dtype=float32), ' intercept: 0.000000')
#
# Step: 26000
# ('input:', array([[ 0.]]))
# 誤差2.97064e-06
# ('weights:', array([[ 0.00019394],
#        [ 0.00019394],
#        [ 0.00019394],
#        [ 0.00019394],
#        [ 0.00019394],
#        [ 0.00019394],
#        [ 0.00019394],
#        [ 0.00019394],
#        [ 0.00019394],
#        [ 0.00019394],
#        [ 0.00019394],
#        [ 0.00019394],
#        [ 0.00019394],
#        [ 0.00019394],
#        [ 0.00019394],
#        [ 0.00019394],
#        [ 0.00019394],
#        [ 0.00019394]], dtype=float32), ' intercept: 0.000000')
#
# Step: 28000
# ('input:', array([[ 0.]]))
# 誤差4.12683e-16
# ('weights:', array([[  1.94828997e-09],
#        [  1.94828997e-09],
#        [  1.94828997e-09],
#        [  1.94828997e-09],
#        [  1.94828997e-09],
#        [  1.94828997e-09],
#        [  1.94828997e-09],
#        [  1.94828997e-09],
#        [  1.94828997e-09],
#        [  1.94828997e-09],
#        [  1.94828997e-09],
#        [  1.94828997e-09],
#        [  1.94828997e-09],
#        [  1.94828997e-09],
#        [  1.94828997e-09],
#        [  1.94828997e-09],
#        [  1.94828997e-09],
#        [  1.94828997e-09]], dtype=float32), ' intercept: 0.000000')
#
# Step: 30000
# ('input:', array([[ 0.]]))
# 誤差76.2186
# ('weights:', array([[ 0.82107782],
#        [ 0.82107782],
#        [ 0.82107782],
#        [ 0.82107782],
#        [ 0.82107782],
#        [ 0.82107782],
#        [ 0.82107782],
#        [ 0.82107782],
#        [ 0.82107782],
#        [ 0.82107782],
#        [ 0.82107782],
#        [ 0.82107782],
#        [ 0.82107782],
#        [ 0.82107782],
#        [ 0.82107782],
#        [ 0.82107782],
#        [ 0.82107782],
#        [ 0.82107782]], dtype=float32), ' intercept: 0.000000')
# Step: 32000
# ('input:', array([[ 0.]]))
# 誤差7.02088e-07
# ('weights:', array([[  8.16159445e-05],
#        [  8.16159445e-05],
#        [  8.16159445e-05],
#        [  8.16159445e-05],
#        [  8.16159445e-05],
#        [  8.16159445e-05],
#        [  8.16159445e-05],
#        [  8.16159445e-05],
#        [  8.16159445e-05],
#        [  8.16159445e-05],
#        [  8.16159445e-05],
#        [  8.16159445e-05],
#        [  8.16159445e-05],
#        [  8.16159445e-05],
#        [  8.16159445e-05],
#        [  8.16159445e-05],
#        [  8.16159445e-05],
#        [  8.16159445e-05]], dtype=float32), ' intercept: 0.000000')
#
# Step: 34000
# ('input:', array([[ 0.]]))
# 誤差1.15265e-05
# ('weights:', array([[ 0.00035329],
#        [ 0.00035329],
#        [ 0.00035329],
#        [ 0.00035329],
#        [ 0.00035329],
#        [ 0.00035329],
#        [ 0.00035329],
#        [ 0.00035329],
#        [ 0.00035329],
#        [ 0.00035329],
#        [ 0.00035329],
#        [ 0.00035329],
#        [ 0.00035329],
#        [ 0.00035329],
#        [ 0.00035329],
#        [ 0.00035329],
#        [ 0.00035329],
#        [ 0.00035329]], dtype=float32), ' intercept: 0.000000')
#
# Step: 36000
# ('input:', array([[ 0.]]))
# 誤差3.11432e-25
# ('weights:', array([[  5.59422165e-14],
#        [  5.59422165e-14],
#        [  5.59422165e-14],
#        [  5.59422165e-14],
#        [  5.59422165e-14],
#        [  5.59422165e-14],
#        [  5.59422165e-14],
#        [  5.59422165e-14],
#        [  5.59422165e-14],
#        [  5.59422165e-14],
#        [  5.59422165e-14],
#        [  5.59422165e-14],
#        [  5.59422165e-14],
#        [  5.59422165e-14],
#        [  5.59422165e-14],
#        [  5.59422165e-14],
#        [  5.59422165e-14],
#        [  5.59422165e-14]], dtype=float32), ' intercept: 0.000000')
#
# Step: 38000
# ('input:', array([[ 0.]]))
# 誤差2.29114e-09
# ('weights:', array([[  4.59061539e-06],
#        [  4.59061539e-06],
#        [  4.59061539e-06],
#        [  4.59061539e-06],
#        [  4.59061539e-06],
#        [  4.59061539e-06],
#        [  4.59061539e-06],
#        [  4.59061539e-06],
#        [  4.59061539e-06],
#        [  4.59061539e-06],
#        [  4.59061539e-06],
#        [  4.59061539e-06],
#        [  4.59061539e-06],
#        [  4.59061539e-06],
#        [  4.59061539e-06],
#        [  4.59061539e-06],
#        [  4.59061539e-06],
#        [  4.59061539e-06]], dtype=float32), ' intercept: 0.000000')
#
# Step: 40000
# ('input:', array([[ 0.]]))
# 誤差6.51093e-19
# ('weights:', array([[  7.68127367e-11],
#        [  7.68127367e-11],
#        [  7.68127367e-11],
#        [  7.68127367e-11],
#        [  7.68127367e-11],
#        [  7.68127367e-11],
#        [  7.68127367e-11],
#        [  7.68127367e-11],
#        [  7.68127367e-11],
#        [  7.68127367e-11],
#        [  7.68127367e-11],
#        [  7.68127367e-11],
#        [  7.68127367e-11],
#        [  7.68127367e-11],
#        [  7.68127367e-11],
#        [  7.68127367e-11],
#        [  7.68127367e-11],
#        [  7.68127367e-11]], dtype=float32), ' intercept: 0.000000')
#
# Step: 42000
# ('input:', array([[ 0.]]))
# 誤差1.27569e-23
# ('weights:', array([[  3.42545789e-13],
#        [  3.42545789e-13],
#        [  3.42545789e-13],
#        [  3.42545789e-13],
#        [  3.42545789e-13],
#        [  3.42545789e-13],
#        [  3.42545789e-13],
#        [  3.42545789e-13],
#        [  3.42545789e-13],
#        [  3.42545789e-13],
#        [  3.42545789e-13],
#        [  3.42545789e-13],
#        [  3.42545789e-13],
#        [  3.42545789e-13],
#        [  3.42545789e-13],
#        [  3.42545789e-13],
#        [  3.42545789e-13],
#        [  3.42545789e-13]], dtype=float32), ' intercept: 0.000000')
#
# Step: 44000
# ('input:', array([[ 0.]]))
# 誤差0.0
# ('weights:', array([[  1.13199534e-29],
#        [  1.13199534e-29],
#        [  1.13199534e-29],
#        [  1.13199534e-29],
#        [  1.13199534e-29],
#        [  1.13199534e-29],
#        [  1.13199534e-29],
#        [  1.13199534e-29],
#        [  1.13199534e-29],
#        [  1.13199534e-29],
#        [  1.13199534e-29],
#        [  1.13199534e-29],
#        [  1.13199534e-29],
#        [  1.13199534e-29],
#        [  1.13199534e-29],
#        [  1.13199534e-29],
#        [  1.13199534e-29],
#        [  1.13199534e-29]], dtype=float32), ' intercept: 0.000000')
#
# Step: 46000
# ('input:', array([[ 0.]]))
# 誤差0.0
# ('weights:', array([[  2.64913951e-28],
#        [  2.64913951e-28],
#        [  2.64913951e-28],
#        [  2.64913951e-28],
#        [  2.64913951e-28],
#        [  2.64913951e-28],
#        [  2.64913951e-28],
#        [  2.64913951e-28],
#        [  2.64913951e-28],
#        [  2.64913951e-28],
#        [  2.64913951e-28],
#        [  2.64913951e-28],
#        [  2.64913951e-28],
#        [  2.64913951e-28],
#        [  2.64913951e-28],
#        [  2.64913951e-28],
#        [  2.64913951e-28],
#        [  2.64913951e-28]], dtype=float32), ' intercept: 0.000000')
#
# Step: 48000
# ('input:', array([[ 0.]]))
# 誤差4.38577e-10
# ('weights:', array([[  2.00848376e-06],
#        [  2.00848376e-06],
#        [  2.00848376e-06],
#        [  2.00848376e-06],
#        [  2.00848376e-06],
#        [  2.00848376e-06],
#        [  2.00848376e-06],
#        [  2.00848376e-06],
#        [  2.00848376e-06],
#        [  2.00848376e-06],
#        [  2.00848376e-06],
#        [  2.00848376e-06],
#        [  2.00848376e-06],
#        [  2.00848376e-06],
#        [  2.00848376e-06],
#        [  2.00848376e-06],
#        [  2.00848376e-06],
#        [  2.00848376e-06]], dtype=float32), ' intercept: 0.000000')
#
# Step: 50000
# ('input:', array([[ 0.]]))
# 誤差2439.66
# ('weights:', array([[ 4.70193291],
#        [ 4.70193291],
#        [ 4.70193291],
#        [ 4.70193291],
#        [ 4.70193291],
#        [ 4.70193291],
#        [ 4.70193291],
#        [ 4.70193291],
#        [ 4.70193291],
#        [ 4.70193291],
#        [ 4.70193291],
#        [ 4.70193291],
#        [ 4.70193291],
#        [ 4.70193291],
#        [ 4.70193291],
#        [ 4.70193291],
#        [ 4.70193291],
#        [ 4.70193291]], dtype=float32), ' intercept: 0.000000')
#
# Step: 52000
# ('input:', array([[ 0.]]))
# 誤差0.00316933
# ('weights:', array([[ 0.00539919],
#        [ 0.00539919],
#        [ 0.00539919],
#        [ 0.00539919],
#        [ 0.00539919],
#        [ 0.00539919],
#        [ 0.00539919],
#        [ 0.00539919],
#        [ 0.00539919],
#        [ 0.00539919],
#        [ 0.00539919],
#        [ 0.00539919],
#        [ 0.00539919],
#        [ 0.00539919],
#        [ 0.00539919],
#        [ 0.00539919],
#        [ 0.00539919],
#        [ 0.00539919]], dtype=float32), ' intercept: 0.000000')
#
# Step: 54000
# ('input:', array([[ 0.]]))
# 誤差0.0
# ('weights:', array([[  5.07247912e-22],
#        [  5.07247912e-22],
#        [  5.07247912e-22],
#        [  5.07247912e-22],
#        [  5.07247912e-22],
#        [  5.07247912e-22],
#        [  5.07247912e-22],
#        [  5.07247912e-22],
#        [  5.07247912e-22],
#        [  5.07247912e-22],
#        [  5.07247912e-22],
#        [  5.07247912e-22],
#        [  5.07247912e-22],
#        [  5.07247912e-22],
#        [  5.07247912e-22],
#        [  5.07247912e-22],
#        [  5.07247912e-22],
#        [  5.07247912e-22]], dtype=float32), ' intercept: 0.000000')
#
# Step: 56000
# ('input:', array([[ 0.]]))
# 誤差0.0
# ('weights:', array([[  1.74433310e-36],
#        [  1.74433310e-36],
#        [  1.74433310e-36],
#        [  1.74433310e-36],
#        [  1.74433310e-36],
#        [  1.74433310e-36],
#        [  1.74433310e-36],
#        [  1.74433310e-36],
#        [  1.74433310e-36],
#        [  1.74433310e-36],
#        [  1.74433310e-36],
#        [  1.74433310e-36],
#        [  1.74433310e-36],
#        [  1.74433310e-36],
#        [  1.74433310e-36],
#        [  1.74433310e-36],
#        [  1.74433310e-36],
#        [  1.74433310e-36]], dtype=float32), ' intercept: 0.000000')
#
# Step: 58000
# ('input:', array([[ 0.]]))
# 誤差2.32049e-13
# ('weights:', array([[  4.23007300e-08],
#        [  4.23007300e-08],
#        [  4.23007300e-08],
#        [  4.23007300e-08],
#        [  4.23007300e-08],
#        [  4.23007300e-08],
#        [  4.23007300e-08],
#        [  4.23007300e-08],
#        [  4.23007300e-08],
#        [  4.23007300e-08],
#        [  4.23007300e-08],
#        [  4.23007300e-08],
#        [  4.23007300e-08],
#        [  4.23007300e-08],
#        [  4.23007300e-08],
#        [  4.23007300e-08],
#        [  4.23007300e-08],
#        [  4.23007300e-08]], dtype=float32), ' intercept: 0.000000')
#
# Step: 60000
# ('input:', array([[ 0.]]))
# 誤差40.3902
# ('weights:', array([[ 0.58800709],
#        [ 0.58800709],
#        [ 0.58800709],
#        [ 0.58800709],
#        [ 0.58800709],
#        [ 0.58800709],
#        [ 0.58800709],
#        [ 0.58800709],
#        [ 0.58800709],
#        [ 0.58800709],
#        [ 0.58800709],
#        [ 0.58800709],
#        [ 0.58800709],
#        [ 0.58800709],
#        [ 0.58800709],
#        [ 0.58800709],
#        [ 0.58800709],
#        [ 0.58800709]], dtype=float32), ' intercept: 0.000000')
# Step: 62000
# ('input:', array([[ 0.]]))
# 誤差0.0
# ('weights:', array([[  1.61559193e-36],
#        [  1.61559193e-36],
#        [  1.61559193e-36],
#        [  1.61559193e-36],
#        [  1.61559193e-36],
#        [  1.61559193e-36],
#        [  1.61559193e-36],
#        [  1.61559193e-36],
#        [  1.61559193e-36],
#        [  1.61559193e-36],
#        [  1.61559193e-36],
#        [  1.61559193e-36],
#        [  1.61559193e-36],
#        [  1.61559193e-36],
#        [  1.61559193e-36],
#        [  1.61559193e-36],
#        [  1.61559193e-36],
#        [  1.61559193e-36]], dtype=float32), ' intercept: 0.000000')
#
# Step: 64000
# ('input:', array([[ 0.]]))
# 誤差4.93655e-12
# ('weights:', array([[  2.13086977e-07],
#        [  2.13086977e-07],
#        [  2.13086977e-07],
#        [  2.13086977e-07],
#        [  2.13086977e-07],
#        [  2.13086977e-07],
#        [  2.13086977e-07],
#        [  2.13086977e-07],
#        [  2.13086977e-07],
#        [  2.13086977e-07],
#        [  2.13086977e-07],
#        [  2.13086977e-07],
#        [  2.13086977e-07],
#        [  2.13086977e-07],
#        [  2.13086977e-07],
#        [  2.13086977e-07],
#        [  2.13086977e-07],
#        [  2.13086977e-07]], dtype=float32), ' intercept: 0.000000')
#
# Step: 66000
# ('input:', array([[ 0.]]))
# 誤差0.0
# ('weights:', array([[  1.61547472e-31],
#        [  1.61547472e-31],
#        [  1.61547472e-31],
#        [  1.61547472e-31],
#        [  1.61547472e-31],
#        [  1.61547472e-31],
#        [  1.61547472e-31],
#        [  1.61547472e-31],
#        [  1.61547472e-31],
#        [  1.61547472e-31],
#        [  1.61547472e-31],
#        [  1.61547472e-31],
#        [  1.61547472e-31],
#        [  1.61547472e-31],
#        [  1.61547472e-31],
#        [  1.61547472e-31],
#        [  1.61547472e-31],
#        [  1.61547472e-31]], dtype=float32), ' intercept: 0.000000')
#
# Step: 68000
# ('input:', array([[ 0.]]))
# 誤差0.0
# ('weights:', array([[  4.10520134e-27],
#        [  4.10520134e-27],
#        [  4.10520134e-27],
#        [  4.10520134e-27],
#        [  4.10520134e-27],
#        [  4.10520134e-27],
#        [  4.10520134e-27],
#        [  4.10520134e-27],
#        [  4.10520134e-27],
#        [  4.10520134e-27],
#        [  4.10520134e-27],
#        [  4.10520134e-27],
#        [  4.10520134e-27],
#        [  4.10520134e-27],
#        [  4.10520134e-27],
#        [  4.10520134e-27],
#        [  4.10520134e-27],
#        [  4.10520134e-27]], dtype=float32), ' intercept: 0.000000')
#
# Step: 70000
# ('input:', array([[ 0.]]))
# 誤差6.73079
# ('weights:', array([[ 0.23046789],
#        [ 0.23046789],
#        [ 0.23046789],
#        [ 0.23046789],
#        [ 0.23046789],
#        [ 0.23046789],
#        [ 0.23046789],
#        [ 0.23046789],
#        [ 0.23046789],
#        [ 0.23046789],
#        [ 0.23046789],
#        [ 0.23046789],
#        [ 0.23046789],
#        [ 0.23046789],
#        [ 0.23046789],
#        [ 0.23046789],
#        [ 0.23046789],
#        [ 0.23046789]], dtype=float32), ' intercept: 0.000000')
#
# Step: 72000
# ('input:', array([[ 0.]]))
# 誤差0.0
# ('weights:', array([[  8.07476772e-38],
#        [  8.07476772e-38],
#        [  8.07476772e-38],
#        [  8.07476772e-38],
#        [  8.07476772e-38],
#        [  8.07476772e-38],
#        [  8.07476772e-38],
#        [  8.07476772e-38],
#        [  8.07476772e-38],
#        [  8.07476772e-38],
#        [  8.07476772e-38],
#        [  8.07476772e-38],
#        [  8.07476772e-38],
#        [  8.07476772e-38],
#        [  8.07476772e-38],
#        [  8.07476772e-38],
#        [  8.07476772e-38],
#        [  8.07476772e-38]], dtype=float32), ' intercept: 0.000000')
#
# Step: 74000
# ('input:', array([[ 0.]]))
# 誤差0.0
# ('weights:', array([[  2.69721622e-31],
#        [  2.69721622e-31],
#        [  2.69721622e-31],
#        [  2.69721622e-31],
#        [  2.69721622e-31],
#        [  2.69721622e-31],
#        [  2.69721622e-31],
#        [  2.69721622e-31],
#        [  2.69721622e-31],
#        [  2.69721622e-31],
#        [  2.69721622e-31],
#        [  2.69721622e-31],
#        [  2.69721622e-31],
#        [  2.69721622e-31],
#        [  2.69721622e-31],
#        [  2.69721622e-31],
#        [  2.69721622e-31],
#        [  2.69721622e-31]], dtype=float32), ' intercept: 0.000000')
#
# Step: 76000
# ('input:', array([[ 0.]]))
# 誤差209.108
# ('weights:', array([[ 1.38685274],
#        [ 1.38685274],
#        [ 1.38685274],
#        [ 1.38685274],
#        [ 1.38685274],
#        [ 1.38685274],
#        [ 1.38685274],
#        [ 1.38685274],
#        [ 1.38685274],
#        [ 1.38685274],
#        [ 1.38685274],
#        [ 1.38685274],
#        [ 1.38685274],
#        [ 1.38685274],
#        [ 1.38685274],
#        [ 1.38685274],
#        [ 1.38685274],
#        [ 1.38685274]], dtype=float32), ' intercept: 0.000000')
#
# Step: 78000
# ('input:', array([[ 0.]]))
# 誤差0.0
# ('weights:', array([[  7.80059583e-38],
#        [  7.80059583e-38],
#        [  7.80059583e-38],
#        [  7.80059583e-38],
#        [  7.80059583e-38],
#        [  7.80059583e-38],
#        [  7.80059583e-38],
#        [  7.80059583e-38],
#        [  7.80059583e-38],
#        [  7.80059583e-38],
#        [  7.80059583e-38],
#        [  7.80059583e-38],
#        [  7.80059583e-38],
#        [  7.80059583e-38],
#        [  7.80059583e-38],
#        [  7.80059583e-38],
#        [  7.80059583e-38],
#        [  7.80059583e-38]], dtype=float32), ' intercept: 0.000000')
#
# Step: 80000
# ('input:', array([[ 0.]]))
# 誤差1.79131e-17
# ('weights:', array([[  4.05911138e-10],
#        [  4.05911138e-10],
#        [  4.05911138e-10],
#        [  4.05911138e-10],
#        [  4.05911138e-10],
#        [  4.05911138e-10],
#        [  4.05911138e-10],
#        [  4.05911138e-10],
#        [  4.05911138e-10],
#        [  4.05911138e-10],
#        [  4.05911138e-10],
#        [  4.05911138e-10],
#        [  4.05911138e-10],
#        [  4.05911138e-10],
#        [  4.05911138e-10],
#        [  4.05911138e-10],
#        [  4.05911138e-10],
#        [  4.05911138e-10]], dtype=float32), ' intercept: 0.000000')
#
# Step: 82000
# ('input:', array([[ 0.]]))
# 誤差0.0
# ('weights:', array([[  1.45142952e-36],
#        [  1.45142952e-36],
#        [  1.45142952e-36],
#        [  1.45142952e-36],
#        [  1.45142952e-36],
#        [  1.45142952e-36],
#        [  1.45142952e-36],
#        [  1.45142952e-36],
#        [  1.45142952e-36],
#        [  1.45142952e-36],
#        [  1.45142952e-36],
#        [  1.45142952e-36],
#        [  1.45142952e-36],
#        [  1.45142952e-36],
#        [  1.45142952e-36],
#        [  1.45142952e-36],
#        [  1.45142952e-36],
#        [  1.45142952e-36]], dtype=float32), ' intercept: 0.000000')
#
# Step: 84000
# ('input:', array([[ 0.]]))
# 誤差3.66511e-07
# ('weights:', array([[  6.00558305e-05],
#        [  6.00558305e-05],
#        [  6.00558305e-05],
#        [  6.00558305e-05],
#        [  6.00558305e-05],
#        [  6.00558305e-05],
#        [  6.00558305e-05],
#        [  6.00558305e-05],
#        [  6.00558305e-05],
#        [  6.00558305e-05],
#        [  6.00558305e-05],
#        [  6.00558305e-05],
#        [  6.00558305e-05],
#        [  6.00558305e-05],
#        [  6.00558305e-05],
#        [  6.00558305e-05],
#        [  6.00558305e-05],
#        [  6.00558305e-05]], dtype=float32), ' intercept: 0.000000')
#
# Step: 86000
# ('input:', array([[ 0.]]))
# 誤差1.38908e-22
# ('weights:', array([[  1.22293386e-12],
#        [  1.22293386e-12],
#        [  1.22293386e-12],
#        [  1.22293386e-12],
#        [  1.22293386e-12],
#        [  1.22293386e-12],
#        [  1.22293386e-12],
#        [  1.22293386e-12],
#        [  1.22293386e-12],
#        [  1.22293386e-12],
#        [  1.22293386e-12],
#        [  1.22293386e-12],
#        [  1.22293386e-12],
#        [  1.22293386e-12],
#        [  1.22293386e-12],
#        [  1.22293386e-12],
#        [  1.22293386e-12],
#        [  1.22293386e-12]], dtype=float32), ' intercept: 0.000000')
#
# Step: 88000
# ('input:', array([[ 0.]]))
# 誤差0.0
# ('weights:', array([[  4.08110752e-20],
#        [  4.08110752e-20],
#        [  4.08110752e-20],
#        [  4.08110752e-20],
#        [  4.08110752e-20],
#        [  4.08110752e-20],
#        [  4.08110752e-20],
#        [  4.08110752e-20],
#        [  4.08110752e-20],
#        [  4.08110752e-20],
#        [  4.08110752e-20],
#        [  4.08110752e-20],
#        [  4.08110752e-20],
#        [  4.08110752e-20],
#        [  4.08110752e-20],
#        [  4.08110752e-20],
#        [  4.08110752e-20],
#        [  4.08110752e-20]], dtype=float32), ' intercept: 0.000000')
#
# Step: 90000
# ('input:', array([[ 0.]]))
# 誤差0.449932
# ('weights:', array([[ 0.06433076],
#        [ 0.06433076],
#        [ 0.06433076],
#        [ 0.06433076],
#        [ 0.06433076],
#        [ 0.06433076],
#        [ 0.06433076],
#        [ 0.06433076],
#        [ 0.06433076],
#        [ 0.06433076],
#        [ 0.06433076],
#        [ 0.06433076],
#        [ 0.06433076],
#        [ 0.06433076],
#        [ 0.06433076],
#        [ 0.06433076],
#        [ 0.06433076],
#        [ 0.06433076]], dtype=float32), ' intercept: 0.000000')
# Step: 92000
# ('input:', array([[ 0.]]))
# 誤差1.75001e-10
# ('weights:', array([[  1.34679442e-06],
#        [  1.34679442e-06],
#        [  1.34679442e-06],
#        [  1.34679442e-06],
#        [  1.34679442e-06],
#        [  1.34679442e-06],
#        [  1.34679442e-06],
#        [  1.34679442e-06],
#        [  1.34679442e-06],
#        [  1.34679442e-06],
#        [  1.34679442e-06],
#        [  1.34679442e-06],
#        [  1.34679442e-06],
#        [  1.34679442e-06],
#        [  1.34679442e-06],
#        [  1.34679442e-06],
#        [  1.34679442e-06],
#        [  1.34679442e-06]], dtype=float32), ' intercept: 0.000000')
#
# Step: 94000
# ('input:', array([[ 0.]]))
# 誤差2290.94
# ('weights:', array([[ 4.25126171],
#        [ 4.25126171],
#        [ 4.25126171],
#        [ 4.25126171],
#        [ 4.25126171],
#        [ 4.25126171],
#        [ 4.25126171],
#        [ 4.25126171],
#        [ 4.25126171],
#        [ 4.25126171],
#        [ 4.25126171],
#        [ 4.25126171],
#        [ 4.25126171],
#        [ 4.25126171],
#        [ 4.25126171],
#        [ 4.25126171],
#        [ 4.25126171],
#        [ 4.25126171]], dtype=float32), ' intercept: 0.000000')
#
# Step: 96000
# ('input:', array([[ 0.]]))
# 誤差202.806
# ('weights:', array([[ 1.19751811],
#        [ 1.19751811],
#        [ 1.19751811],
#        [ 1.19751811],
#        [ 1.19751811],
#        [ 1.19751811],
#        [ 1.19751811],
#        [ 1.19751811],
#        [ 1.19751811],
#        [ 1.19751811],
#        [ 1.19751811],
#        [ 1.19751811],
#        [ 1.19751811],
#        [ 1.19751811],
#        [ 1.19751811],
#        [ 1.19751811],
#        [ 1.19751811],
#        [ 1.19751811]], dtype=float32), ' intercept: 0.000000')
#
# Step: 98000
# ('input:', array([[ 0.]]))
# 誤差1.47576e-35
# ('weights:', array([[  4.32270552e-19],
#        [  4.32270552e-19],
#        [  4.32270552e-19],
#        [  4.32270552e-19],
#        [  4.32270552e-19],
#        [  4.32270552e-19],
#        [  4.32270552e-19],
#        [  4.32270552e-19],
#        [  4.32270552e-19],
#        [  4.32270552e-19],
#        [  4.32270552e-19],
#        [  4.32270552e-19],
#        [  4.32270552e-19],
#        [  4.32270552e-19],
#        [  4.32270552e-19],
#        [  4.32270552e-19],
#        [  4.32270552e-19],
#        [  4.32270552e-19]], dtype=float32), ' intercept: 0.000000')
#
# Step: 100000
# ('input:', array([[ 0.]]))
# 誤差4.59897e-28
# ('weights:', array([[  1.90505672e-15],
#        [  1.90505672e-15],
#        [  1.90505672e-15],
#        [  1.90505672e-15],
#        [  1.90505672e-15],
#        [  1.90505672e-15],
#        [  1.90505672e-15],
#        [  1.90505672e-15],
#        [  1.90505672e-15],
#        [  1.90505672e-15],
#        [  1.90505672e-15],
#        [  1.90505672e-15],
#        [  1.90505672e-15],
#        [  1.90505672e-15],
#        [  1.90505672e-15],
#        [  1.90505672e-15],
#        [  1.90505672e-15],
#        [  1.90505672e-15]], dtype=float32), ' intercept: 0.000000')

# %%
# Out:
# RuntimeErrorTraceback (most recent call last)
# <ipython-input-103-4d75de485998> in <module>()
# ----> 1 print(sess.run(a))
#
# /home/kaggleuser/.local/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in run(self, fetches, feed_dict, options, run_metadata)
#     885     try:
#     886       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 887                          run_metadata_ptr)
#     888       if run_metadata:
#     889         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /home/kaggleuser/.local/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1031     # Check session.
#    1032     if self._closed:
# -> 1033       raise RuntimeError('Attempted to use a closed Session.')
#    1034     if self.graph.version == 0:
#    1035       raise RuntimeError('The Session graph is empty.  Add operations to the '
#
# RuntimeError: Attempted to use a closed Session.
